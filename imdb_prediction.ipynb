# %%
import numpy as np
import tensorflow
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import sequence

# %%
word_index=imdb.get_word_index()
reverse_word_index={values:key for key,values in word_index.items()}
# Out:
# ...
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model=load_model("/content/drive/MyDrive/imdb_project_files/imdb_simple_RNN_model.keras")
print("model is loded")
# Out:
# model is loded

# %%
def preprocess_text(text):
  words=text.lower().split()
  encoded_review=[word_index.get(word,2)+3 for word in words]
  padded_review=sequence.pad_sequences([encoded_review], maxlen=500)
  return padded_review


def decode_review(encoded_review):
  return ' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])

# %%
def predict_sentiment(review):
  preprocessed_input=preprocess_text(review)

  prediction=model.predict(preprocessed_input)

  sentiment='Positive' if prediction[0][0]>0.5 else 'Negitive'

  return sentiment,prediction

# %%
example_review='i am a very beautiful girl, with a very beautiful heart. i am fantastic with a very high problem solving skill.'
predict_sentiment(example_review)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# ('Positive', array([[0.96239626]], dtype=float32))
